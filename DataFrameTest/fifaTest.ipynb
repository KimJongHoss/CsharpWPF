// %%
#r "nuget:Microsoft.Data.Analysis,0.21.0"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Data.Analysis, 0.21.0</span></li></ul></div></div>
// Loading extensions from `C:\Users\jongho\.nuget\packages\microsoft.data.analysis\0.21.0\interactive-extensions\dotnet\Microsoft.Data.Analysis.Interactive.dll`

// %%
using Microsoft.Data.Analysis;

// %%
using System.IO;
using System.Linq;

// Define data path
var dataPath = Path.GetFullPath(@"fifa.csv");

// Load the data into the data frame
var dataFrame = DataFrame.LoadCsv(dataPath);

// %%
dataFrame
// Out:
// <table id="table_638580146651524645"><caption><h3 style="text-align: center;">DataFrame - 286 rows </h3></caption><thead><tr><th><i>index</i></th><th>Date</th><th>ARG</th><th>BRA</th><th>ESP</th><th>FRA</th><th>GER</th><th>ITA</th></tr></thead><tbody><tr style="display: none"><td><i><div class="dni-plaintext"><pre>0</pre></div></i></td><td><span>1993-08-08 00:00:00Z</span></td><td><div class="dni-plaintext"><pre>5</pre></div></td><td><div class="dni-plaintext"><pre>8</pre></div></td><td><div class="dni-plaintext"><pre>13</pre></div></td><td><div class="dni-plaintext"><pre>12</pre></div></td><td><div class="dni-plaintext"><pre>1</pre></div></td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr style="display: none"><td><i><div class="dni-plaintext"><pre>1</pre></div></i></td><td><span>1993-09-23 00:00:00Z</span></td><td><div class="dni-plaintext"><pre>12</pre></div></td><td><div class="dni-plaintext"><pre>1</pre></div></td><td><div class="dni-plaintext"><pre>14</pre></di
// ...

// %%
private static double solveMean(double[] values)
{
  if (values is null)
    throw new ArgumentNullException(nameof(values));

  if (values.Length == 0)
    throw new ArgumentException($"{nameof(values)} must not be empty");

  double sum = 0;
  for (int i = 0; i < values.Length; i++)
    sum += values[i];

  double mean = sum / values.Length;

  return mean;
}

// %%
foreach (DataFrameColumn col in dataFrame.Columns.Skip(1))
{
    // warning: additional care must be taken for datasets which contain null
    double[] values = Enumerable.Range(0, (int)col.Length).Select(x => Convert.ToDouble(col[x])).ToArray();
    double mean = solveMean(values);
    Console.WriteLine($"{col.Name}의 평균 순위 = {mean}(n={values.Length})");
}
// Out:
// ARG의 평균 순위 = 5.454545454545454(n=286)
// BRA의 평균 순위 = 3.1713286713286712(n=286)
// ESP의 평균 순위 = 5.321678321678322(n=286)
// FRA의 평균 순위 = 8.958041958041958(n=286)
// GER의 평균 순위 = 5.104895104895105(n=286)
// ITA의 평균 순위 = 8.353146853146853(n=286)

// %%
var selectGER_2000 = dataFrame.Rows
    .Where(row => ((DateTime)row["Date"]).Year == 2000)
    .Select(row => Convert.ToDouble(row["GER"]))
    .ToList();

    double meanGER_2000 = selectGER_2000.Average();

    Console.WriteLine($"2000년의 독일 평균 순위 = {meanGER_2000}등");
// Out:
// 2000년의 독일 평균 순위 = 7.333333333333333등

// %%
#r "nuget:ScottPlot, 5.0.36"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>ScottPlot, 5.0.36</span></li></ul></div></div>
// Loading extensions from `C:\Users\jongho\.nuget\packages\skiasharp\2.88.8\interactive-extensions\dotnet\SkiaSharp.DotNet.Interactive.dll`

// %%
using Microsoft.DotNet.Interactive.Formatting;
Formatter.Register(typeof(ScottPlot.Plot), (p, w) => 
    w.Write(((ScottPlot.Plot)p).GetImageHtml(400, 300)), HtmlFormatter.MimeType);

// %%
using ScottPlot;
using Microsoft.Data.Analysis;
using System;
using System.Linq;

// %%
var dateArray = dataFrame.Columns["Date"].Cast<DateTime>().Select(date => date.ToOADate()).ToArray();
var ARGArray = dataFrame.Columns["ARG"].Cast<float>().ToArray();
var BRAArray = dataFrame.Columns["BRA"].Cast<float>().ToArray();

ScottPlot.Plot myPlot1 = new();
var argGrape = myPlot1.Add.Scatter(dateArray, ARGArray);
argGrape.LegendText = "ARG";
var braGrape = myPlot1.Add.Scatter(dateArray, BRAArray);
braGrape.LegendText = "BRA";

myPlot1.ShowLegend();
myPlot1.Axes.DateTimeTicksBottom();

myPlot1
// Out:
// <img src="data:image/png;base64,..."></img>

// %%
var selectFRAover_2001 = dataFrame.Rows
    .Where(row => ((DateTime)row["Date"]).Year > 2001)
    .Select(row => Convert.ToDouble(row["FRA"]))
    .ToList();

    selectFRAover_2001
// Out:
// <div class="dni-plaintext"><pre>[ 1, 1, 1, 1, 1, 3, 4, 2, 2, 2, 2, 2, 2, 3, 3, 2, 2, 2, 2, 2 ... (175 more) ]</pre></div><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %%
var dateArray2 = dataFrame.Rows
    .Where(row => ((DateTime)row["Date"]).Year > 2001)  // 2001년 이후 필터링
    .Select(row => ((DateTime)row["Date"]).ToOADate())  // 날짜를 double로 변환
    .ToArray();
var FRAArray = selectFRAover_2001.ToArray();
ScottPlot.Plot myPlot2 = new();
myPlot2.Add.Scatter(dateArray2, FRAArray);

ScottPlot.Statistics.LinearRegression reg = new(dateArray2, FRAArray);

Coordinates pt1 = new(dateArray2.First(), reg.GetValue(dateArray2.First()));
Coordinates pt2 = new(dateArray2.Last(), reg.GetValue(dateArray2.Last()));
var line = myPlot2.Add.Line(pt1, pt2);
line.MarkerSize = 0;
line.LineWidth = 2;
line.LinePattern = LinePattern.Solid;

myPlot2.Axes.DateTimeTicksBottom();

myPlot2
// Out:
// <img src="data:image/png;base64,..."></img>
